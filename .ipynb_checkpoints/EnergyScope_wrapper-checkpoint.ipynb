# %% [markdown]
# # INITIAL MODEL

# %%
import os
from pathlib import Path
import pandas as pd
import energyscope as es
from amplpy import AMPL
from energyscope.postprocessing.draw_sankey.Sankey_Louis import Sankey_plot
model_directory = "/Users/achuat/Documents/Projects/Governance_EnergyScope/EnergyScopePy_dev/case_studies_initial/"
os.system('/Applications/ampl/ampl_lic start')
ampl = AMPL()
ampl.set_option("solver", 'gurobi')
# Read the model and data files.
ampl.read(os.path.join(model_directory, "es_model.mod"))
ampl.read_data(os.path.join(model_directory, "ESTD_data.dat"))
ampl.read_data(os.path.join(model_directory, "ESTD_12TD.dat"))
ampl.solve()
# Out:
# 20240109 15:30:47: ampl_lic is already running.
#
# AMPL network license manager version 20210929 (Darwin 10.8.0 x86_64).
# Gurobi 10.0.2: Gurobi 10.0.2: optimal solution; objective 43941.28319
# 45290 simplex iterations
# 106 barrier iterations

# %% [raw]
# totalcost = ampl.get_variable("TotalCost").get_values().to_pandas()
# print(totalcost)
# totalgwp = ampl.get_variable("TotalGWP").get_values().to_pandas()
# print(totalgwp)
# df_ini = ampl.get_variable("F").get_values().to_pandas()
# df_ini[df_ini!=0].dropna().plot.bar()

# %% [markdown]
# # Plotting the Sankey diagram from the amplpy object

# %%
sto = pd.read_table('case_studies_initial/output/sto_year.txt')
sto.rename(columns={'Year flux [TWh]ELECTRICITY':'ELECTRICITY','Storage tech':'Tech'},inplace=True)
flo = pd.read_table('case_studies_initial/output/year_balance.txt')
#flo.rename(columns={'Year flux [TWh]ELECTRICITY':'ELECTRICITY','Storage tech':'tech'},inplace=True)

Sankey_plot(flo,sto)
# Out:
#      index                Tech    ELECTRICITY  GASOLINE    DIESEL  LFO  GAS  \
# 0        0        ELECTRICITY     5374.142237  0.000000  0.000000  0.0  0.0
# 1        1           GASOLINE        0.000000  0.000581  0.000000  0.0  0.0
# 2        2             DIESEL        0.000000  0.000000  0.001175  0.0  0.0
# 3        3         BIOETHANOL        0.000000  0.000534  0.000000  0.0  0.0
# 4        4          BIODIESEL        0.000000  0.000000  0.000747  0.0  0.0
# ..     ...                 ...            ...       ...       ...  ...  ...
# 136    136        LFO_STORAGE        0.000000  0.000000  0.000000 -0.0  0.0
# 137    137    AMMONIA_STORAGE        0.000000  0.000000  0.000000  0.0  0.0
# 138    138   METHANOL_STORAGE        0.000000  0.000000  0.000000  0.0  0.0
# 139    139        CO2_STORAGE        0.000000  0.000000  0.000000  0.0  0.0
# 140    140    END_USES_DEMAND   113082.998077  0.000000  0.000000  0.0  0.0
#
# ...

# %%
# Function to use Sankey_plot using Louis function base 

# Louis input: df = flow between techno + storage = flow of energy stored over time 
# new input: obj amplpy


F_t = ampl.get_variable("F_t").get_values().to_pandas().reset_index().rename(columns={"index0": "tech_name", "index1": "h","index2": "td","F_t.val": "value"})
lyrio = ampl.get_parameter("layers_in_out").get_values().to_pandas().reset_index().rename(columns={"index0": "tech_name", "index1": "flow_name","layers_in_out": "value"})
HOUR_OF_PERIOD = pd.DataFrame(ampl.get_entity("T_H_TD").get_values().to_list(), columns=['i','h','td']).set_index('i')

df_flow = F_t.groupby(['tech_name','td']).sum().drop(['h'],axis=1).join(HOUR_OF_PERIOD.groupby('td').count(),on ='td')
df_flow['value'] = df_flow['value'] * df_flow['h']
df_flow = df_flow.merge(lyrio.rename(columns={'value':'value_lyrio'}), on='tech_name')
df_flow['value'] = (df_flow['value_lyrio'] * df_flow['h'])

df_storage = 1

df_flo = df_flow
df_sto = ampl
list_storage = ["BATT_LI", "BEV_BATT", "PHEV_BATT", "PHS", "TS_DEC_DIRECT_ELEC", "TS_DEC_HP_ELEC",
                    "TS_DEC_THHP_GAS", "TS_DEC_COGEN_GAS", "TS_DEC_COGEN_OIL", "TS_DEC_ADVCOGEN_GAS",
                    "TS_DEC_ADVCOGEN_H2", "TS_DEC_BOILER_GAS", "TS_DEC_BOILER_WOOD", "TS_DEC_BOILER_OIL",
                    "TS_DHN_DAILY", "TS_DHN_SEASONAL", "TS_HIGH_TEMP", "H2_STORAGE"]
#list_storage = ampl.get_set("STORAGE_TECH").get_values().to_pandas().index.values
df_flow
# Out:
#       tech_name   value     h     flow_name  value_lyrio
# 0       AMMONIA  1440.0  1440       AMMONIA          1.0
# 1       AMMONIA     0.0  1440       CO2_ATM          0.0
# 2       AMMONIA     0.0  1440  CO2_CAPTURED          0.0
# 3       AMMONIA     0.0  1440  CO2_INDUSTRY          0.0
# 4       AMMONIA     0.0  1440          COAL          0.0
# ...         ...     ...   ...           ...          ...
# 40015      WOOD     0.0   576      RES_WIND          0.0
# 40016      WOOD     0.0   576       URANIUM          0.0
# 40017      WOOD     0.0   576         WASTE          0.0
# 40018      WOOD     0.0   576   WET_BIOMASS          0.0
# 40019      WOOD   576.0   576          WOOD          1.0
#
# [40020 rows x 5 columns]

# %% [markdown]
# # INFRASTRUCTURE

# %%
model_directory = "/Users/achuat/Documents/Projects/Governance_EnergyScope/EnergyScopePy_dev/case_studies/Infrastructure/"

ampl = AMPL()
ampl.set_option("solver", 'gurobi')
# Read the model and data files.
ampl.read(os.path.join(model_directory, "es_model.mod"))
ampl.read_data(os.path.join(model_directory, "ESTD_data.dat"))
ampl.read_data(os.path.join(model_directory, "ESTD_12TD.dat"))
ampl.solve()
totalcost = ampl.get_variable("TotalCost").get_values().to_pandas()
print(totalcost)
totalgwp = ampl.get_variable("TotalGWP").get_values().to_pandas()
print(totalgwp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 model_directory = "/Users/achuat/Documents/Projects/Governance_EnergyScope/EnergyScopePy_dev/case_studies/Infrastructure/"
# ----> 3 ampl = AMPL()
#       4 ampl.set_option("solver", 'gurobi')
#       5 # Read the model and data files.
#
# NameError: name 'AMPL' is not defined

# %%
data = ampl.get_parameter('layers_in_out').get_values().toPandas()
data
# Out:
#                       layers_in_out
# index0  index1
# AMMONIA AMMONIA                 1.0
#         CO2_ATM                 0.0
#         CO2_CAPTURED            0.0
#         CO2_INDUSTRY            0.0
#         COAL                    0.0
# ...                             ...
# WOOD    RES_WIND                0.0
#         URANIUM                 0.0
#         WASTE                   0.0
#         WET_BIOMASS             0.0
#         WOOD                    1.0
#
# [6042 rows x 1 columns]

# %%
totalcost = ampl.get_variable("TotalCost").get_values().to_pandas()
print(totalcost)
totalgwp = ampl.get_variable("TotalGWP").get_values().to_pandas()
print(totalgwp)
# Out:
#    TotalCost.val
# 0              0
#    TotalGWP.val
# 0             0

# %%
df_infra = ampl.get_variable("F").get_values().to_pandas()
df_infra[df_infra!=0].dropna().plot.bar()
# Out:
# <Axes: >

# %%
df_infra[df_infra!=0].dropna()
# Out:
#                F.val
# EFFICIENCY  0.985222

# %%
df_infra
# Out:
#                  F.val
# AMMONIA_STORAGE    0.0
# AMMONIA_TO_H2      0.0
# ATM_CCS            0.0
# BATT_LI            0.0
# BEV_BATT           0.0
# ...                ...
# TS_DHN_DAILY       0.0
# TS_DHN_SEASONAL    0.0
# TS_HIGH_TEMP       0.0
# WIND_OFFSHORE      0.0
# WIND_ONSHORE       0.0
#
# [147 rows x 1 columns]

# %% [markdown]
# ## Comparison

# %%
df_diff = df_ini-df_infra
print(df_diff)
# Out:
#                       F.val
# AMMONIA_STORAGE    0.000000
# AMMONIA_TO_H2      0.000000
# ATM_CCS            0.000000
# BATT_LI            0.000000
# BEV_BATT         175.560136
# ...                     ...
# TS_DHN_DAILY       0.000000
# TS_DHN_SEASONAL  913.937618
# TS_HIGH_TEMP       1.834661
# WIND_OFFSHORE      6.000000
# WIND_ONSHORE      10.000000
#
# [148 rows x 1 columns]

# %%
df_diff[df_diff>1e-1].dropna().plot.bar()
# Out:
# <Axes: >
